# %% [markdown]
# String Indexing

# %%
name = "Vashnvi"

nameshort = name[0:4] #start from index 0 all the way till 3(excluding 3)
print(nameshort)

character1 = name[4]
print(character1)
# Out:
# Vash
# n

# %% [markdown]
# Slicing

# %%
name = "Vashnavi"
print(name[-4:-1])
print(name[1:4])
print(name[:4])#is same as print[0:4]
print(name[1:])#is same as print[1:5]
print(name[1:5])
# Out:
# nav
# ash
# Vash
# ashnavi
# ashn

# %% [markdown]
# Skipping

# %%
a = "1234567890"
print(a[1:9:2])
print(a[1:5])

w = "amazing"
print(w[:7])
print(w[0:])
# Out:
# 2468
# 2345
# amazing
# amazing

# %% [markdown]
# String Functions

# %% [markdown]
# 1. Lenght = len() returns the length of the string.

# %%
str = "vashnavi"

print(len(str))
# Out:
# 8

# %% [markdown]
# 2. Endswith = endswith() checks if a string ends with given text.

# %%
str = "vashnavi"
print(str.endswith("navi"))
print(str.endswith("ere"))
print(str.startswith("vas"))
# Out:
# True
# False
# True

# %% [markdown]
# 3.  Count = count() counts total occurrences of a character.

# %%
name = "vashnavi"
count = name.count("a")
print(count)
# Out:
# 2

# %% [markdown]
# 4. Capitalize = capitalize() capitalizes the first character.

# %%
str = "vashnavi"
capitalized = str.capitalize()
print(capitalized)
# Out:
# Vashnavi

# %% [markdown]
# 5. Find = find() returns the index of first occurrence.

# %%
str = "Vashnavi"
index = str.find("h")
print(index) # Output: 2
# Out:
# 3

# %% [markdown]
# 6. Replace = replace(old word, new word) replaces the old word with the new word in the string.

# %%
str = "vashnavi"
replaced = str.replace("a", "l")
print(replaced)
# Out:
# vlshnlvi

# %% [markdown]
# ESCAPE SEQUENCE CHARACTERS

# %%
a = "vashnavi is a good girl\nbut not a bad girl"
print(a)
# Out:
# vashnavi is a good girl
# but not a bad girl

# %%
a = "vashnavi is \"good\""
print(a)
# Out:
# vashnavi is "good"

# %% [markdown]
# problem 1.
# Write a python program to display a user entered name followed by Good Afternoon using
# input() function.

# %%
name = str(input("Enter your name: "))
print(f"{name} Good Afternoon")
# Out:
# v Good Afternoon

# %% [markdown]
# problem 2.
#  Write a program to fill in a letter template given below with name and date.

# %%
letter = '''
Dear <|Name|>,
You are selected!
<|Date|>
'''

print(letter.replace('<|Name|>', 'Vashnavi').replace('<|Date|>', 'Jan 1, 2029'))
# Out:
# Dear Vashnavi,
# You are selected!
# Jan 1, 2029

# %% [markdown]
# problem 3. Write a program to detect double space in a string.

# %%
name = "Vashnavi  is a good  girl and  happy"
print(name.find("  "))
# Out:
# 8

# %% [markdown]
# problem 4. Replace the double space from problem 3 with single spaces.

# %%
name = "vashnavi  is a  good girl"
print(name.replace("  ", " "))
# Out:
# vashnavi is a good girl

# %% [markdown]
# problem 5. Write a program to format the following letter using escape sequence characters.

# %%
letter = "Dear Harry,\n\tThis python course is nice.\n Thanks!"
print(letter)
# Out:
# Dear Harry,
# 	This python course is nice.
#  Thanks!
